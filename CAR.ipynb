# %%
import numpy as  np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\sneha\Downloads\car_price_dataset.csv")

# %%
df.describe()
# Out:
#                Year   Engine_Size        Mileage         Doors   Owner_Count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              Price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Engine_Size', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Doors', 'Owner_Count', 'Price'],
#       dtype='object')

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['Brand'],df['Model'])
plt.xlabel('Brand')
plt.ylabel('Model')
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Transmission")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Engine_Size', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Doors', 'Owner_Count', 'Price'],
#       dtype='object')

# %%
columns_plot=['Brand', 'Model', 'Year', 'Engine_Size', 'Fuel_Type', 
        'Transmission']
for i in columns_plot:
    bar_plot(i)
# Out:
# Brand:
#  Brand
# Ford          1048
# Audi          1038
# Volkswagen    1020
# Honda         1009
# Chevrolet     1003
# BMW            999
# Hyundai        995
# Kia            976
# Toyota         970
# Mercedes       942
# Name: count, dtype: int64
# Model:
#  Model
# Accord      365
# Fiesta      363
# Impala      355
# 5 Series    353
# Tiguan      352
# Focus       351
# Q5          350
# A4          350
# Elantra     347
# Golf        339
# A3          338
# Optima      336
# Civic       336
# 3 Series    335
# Explorer    334
# Malibu      333
# Tucson      329
# Passat      329
# Rio         327
# Corolla     325
# RAV4        324
# Camry       321
# E-Class     321
# Sonata      319
# Equinox     315
# GLA         315
# Sportage    313
# X5          311
# CR-V        308
# C-Class     306
# Name: count, dtype: int64
# Year:
#  Year
# 2002    462
# 2011    449
# 2023    448
# 2012    437
# 2017    433
# 2010    431
# 2005    431
# 2007    430
# 2015    426
# 2018    425
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Engine_Size', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Doors', 'Owner_Count', 'Price'],
#       dtype='object')

# %%
df[['Doors','Price']].groupby(['Doors'],as_index=False).mean().sort_values(by='Price',ascending=False)
# Out:
#    Doors        Price
# 0      2  8928.931161
# 3      5  8900.352606
# 2      4  8841.587908
# 1      3  8746.446602

# %%
df[['Owner_Count','Fuel_Type']].groupby(['Owner_Count'],as_index=False).count().sort_values(by='Fuel_Type',ascending=False)
# Out:
#    Owner_Count  Fuel_Type
# 0            1       2036
# 4            5       2036
# 1            2       2020
# 2            3       1977
# 3            4       1931

# %%
df[['Year','Mileage']].groupby(['Year'],as_index=False).count().sort_values(by='Mileage',ascending=False)
# Out:
#     Year  Mileage
# 2   2002      462
# 11  2011      449
# 23  2023      448
# 12  2012      437
# 17  2017      433
# 10  2010      431
# 5   2005      431
# 7   2007      430
# 15  2015      426
# 18  2018      425
# 13  2013      422
# 19  2019      421
# 14  2014      417
# 6   2006      415
# 20  2020      415
# 1   2001      406
# 9   2009      399
# 22  2022      397
# 16  2016      395
# 4   2004      394
# 0   2000      393
# 21  2021      391
# 8   2008      382
# 3   2003      381

# %%
sns.boxplot(df['Engine_Size'])
# Out:
# <Axes: ylabel='Engine_Size'>

# %%
df["Fuel_Type"]=df["Fuel_Type"].fillna(df["Fuel_Type"].count())

# %%
df["Year"]=df["Year"].fillna(df["Year"].count())

# %%
df.isnull().sum()
# Out:
# Brand           0
# Model           0
# Year            0
# Engine_Size     0
# Fuel_Type       0
# Transmission    0
# Mileage         0
# Doors           0
# Owner_Count     0
# Price           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Engine_Size', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Doors', 'Owner_Count', 'Price'],
#       dtype='object')

# %%
df.drop(labels=['Brand','Model','Year','Fuel_Type','Price'],axis=1,inplace=True)

# %%
df.drop
# Out:
# <bound method DataFrame.drop of       Engine_Size    Transmission  Mileage  Doors  Owner_Count
# 0             4.2          Manual   289944      3            5
# 1             2.0       Automatic     5356      2            3
# 2             4.2       Automatic   231440      4            2
# 3             2.0          Manual   160971      2            1
# 4             2.6  Semi-Automatic   286618      3            3
# ...           ...             ...      ...    ...          ...
# 9995          3.7  Semi-Automatic     5794      2            4
# 9996          1.4       Automatic   168000      2            1
# 9997          3.0       Automatic    86664      5            1
# 9998          1.4       Automatic   225772      4            1
# 9999          2.1          Manual   157882      3            3
#
# [10000 rows x 5 columns]>

# %%
import pandas as pd
df['Brand'] = pd.get_dummies(df['Brand'],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 import pandas as pd
# ----> 2 df['Brand'] = pd.get_dummies(df['Brand'],drop_first=True)
#
# NameError: name 'df' is not defined
